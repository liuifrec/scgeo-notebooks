# %% [markdown]
# # Distribution and aggregation audit
# Pooled-cell distances, computational cell-label nulls, biological-mouse summaries, and exact mouse-label permutations are exposed as distinct evidence types. Cells are never interpreted as biological replicates.

# %%
from pathlib import Path
import pandas as pd
root=Path.cwd().resolve()
while root != root.parent and not (root/'results').is_dir(): root=root.parent
inventory=pd.read_csv(root/'results/revision_finalization/reviewer2/distribution_test_inventory.csv')
inventory.groupby(['dataset','comparison_unit','inferential_status'],dropna=False).size()
