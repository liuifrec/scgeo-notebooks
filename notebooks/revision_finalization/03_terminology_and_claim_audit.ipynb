# %% [markdown]
# # Terminology and claim audit
# This audit replaces overbroad biological-preservation, OOD, independent-confirmation, and longitudinal language with representation- and design-specific wording. Controlled synthetic corruption remains described as controlled corruption, not general OOD detection.
#
# ## Reader guide
#
# - **Purpose:** Terminology and claim audit in the frozen revision workflow.
# - **Inference scope:** Presentation and documentation audit of frozen evidence. This notebook does not recompute or alter numerical results.
# - **Inputs:** Frozen synthetic, pancreas, Dataset B, official R Augur, and Dataset C artifacts.
# - **Implementation:** `scripts/assemble_reviewer2_repairs.py`.
# - **Outputs:** Ignored `results/revision_finalization/` reviewer-evidence artifacts.
# - **Frozen findings:** Expose frozen metric definitions, comparison units, negative evidence, terminology corrections, and limitations without numerical modification.
# - **Limitations:** The outputs support manuscript and response-letter editing but do not replace scientific judgment or create new evidence.
#
# This source notebook is intentionally a thin, output-free entry point. The testable implementation is maintained in scripts/assemble_reviewer2_repairs.py. Executed review copies and generated artifacts are written under the ignored results directory.

# %%
from pathlib import Path
import pandas as pd
root=Path.cwd().resolve()
while root != root.parent and not (root/'results').is_dir(): root=root.parent
replacements=pd.read_csv(root/'results/revision_finalization/reviewer2/terminology_replacement_inventory.csv')
replacements[['source_path','original_wording','corrected_wording','reason']]
