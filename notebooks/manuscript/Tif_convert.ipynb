# %%
from PIL import Image

img = Image.open("Figure1.tiff")
img.save("Figure1.tif", compression="tiff_lzw")
img = Image.open("Figure2.tiff")
img.save("Figure2.tif", compression="tiff_lzw")
img = Image.open("Figure3.tiff")
img = img.resize((3000, int(img.height * 3000 / img.width)))
img.save("Figure3.tif", compression="tiff_lzw")
img = Image.open("Figure4.tiff")
img = img.resize((3000, int(img.height * 3000 / img.width)))
img.save("Figure4.tif", compression="tiff_lzw")
