# %% [markdown]
# # GSE211713 C7 v2 — canonical cross-contrast assembly
# Assembly reads only the explicit manifest, rejects summaries as inputs, and fails on duplicate or forbidden keys.

# %%
from scripts.gse211713_scgeo_common import assemble_canonical_outputs
report = assemble_canonical_outputs()
report
