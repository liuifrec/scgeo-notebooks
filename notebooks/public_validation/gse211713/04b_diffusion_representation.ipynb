# %% [markdown]
# # GSE211713 C6 v2: 04b_diffusion_representation
# Repaired canonical representation stage. Source notebook intentionally contains no outputs.
#
# ## Reader guide
#
# - **Purpose:** GSE211713 C6 v2: 04b_diffusion_representation in the frozen revision workflow.
# - **Inference scope:** Dataset C primary contrasts are replicate-aware associations using independent mouse/GSM libraries. Early and late groups are cross-sectional, not longitudinal.
# - **Inputs:** Frozen compact and annotated H5AD inputs with approved representation settings.
# - **Implementation:** `scripts/gse211713_representation_common.py`.
# - **Outputs:** Ignored `results/public_validation/gse211713_dataset_c/` artifacts.
# - **Frozen findings:** Retain the frozen early representation sensitivity, late five-of-six major-state stability, broad early-versus-late differences, and fibroblast-subtype sensitivity.
# - **Limitations:** Small mouse counts limit exact-permutation resolution; related contrasts reuse controls; annotations are marker-inferred; UMAP is display-only; no causality or longitudinal change is established.
#
# This source notebook is intentionally a thin, output-free entry point. The testable implementation is maintained in scripts/gse211713_representation_common.py. Executed review copies and generated artifacts are written under the ignored results directory.

# %%
from scripts.gse211713_representation_common import run_diffusion_stage
run_diffusion_stage()
