# %% [markdown]
# # GSE211713 C7 v2 — control versus 17 Gy late
# Replicate-aware primary analysis using qualified mouse-level state centers.

# %%
from scripts.gse211713_scgeo_common import run_contrast
report = run_contrast('control_vs_17gy_late', 'major')
report
