# %% [markdown]
# # GSE211713 C6 v2: 04a_pca_representations
# Repaired canonical representation stage. Source notebook intentionally contains no outputs.

# %%
from scripts.gse211713_representation_common import run_pca_stage
run_pca_stage()
