# %% [markdown]
# # GSE211713 C6 v2: 04c_scvi_representation
# Repaired canonical representation stage. Source notebook intentionally contains no outputs.

# %%
from scripts.gse211713_representation_common import run_scvi_stage
run_scvi_stage()
