# %% [markdown]
# # Dataset B Phase 3C — ScGeo and official R Augur comparison
#
# Official R Augur 1.0.3 at commit b252b84e4af687d9817813b1db409267eb44ec3f is the primary external comparator. Its AUC measures treatment separability; ScGeo measures state displacement geometry and representation stability. The Augur-inspired Python approximation is retained only in a supplementary implementation-sensitivity panel and is never averaged, merged, or selected with official AUC. Rank correlations cover only seven marker-inferred states. Abundance and distributional statistics remain separate; all results are descriptive_only, with no composite score or biological-replicate inference.
#
# ## Reader guide
#
# - **Purpose:** Dataset B Phase 3C — ScGeo and official R Augur comparison in the frozen revision workflow.
# - **Inference scope:** Dataset B is descriptive_only because no valid biological-replicate identity was recovered. Cells, conditions, libraries, and inferred partitions are not replicates.
# - **Inputs:** Frozen Dataset B ScGeo, official R Augur, sensitivity, and evidence artifacts.
# - **Implementation:** `scripts/gse249479_augur_common.py`.
# - **Outputs:** Ignored `results/public_validation/gse249479_dataset_b/` artifacts.
# - **Frozen findings:** Retain the accepted descriptive TNF/LPS geometry, representation sensitivity, signature, abundance/distribution, and official R Augur evidence. The Python comparator remains supplementary only.
# - **Limitations:** No population-level biological inference is available; nested PCA views are not independent confirmations and UMAP is display-only.
#
# This source notebook is intentionally a thin, output-free entry point. The testable implementation is maintained in scripts/gse249479_augur_common.py. Executed review copies and generated artifacts are written under the ignored results directory.

# %%
from scripts.gse249479_augur_common import run_comparison
summary = run_comparison()
summary
