# %% [markdown]
# # GSE249479 Phase 3B — PBS versus LPS descriptive ScGeo geometry
#
# This notebook uses frozen ScGeo defaults without a sample key. All cell bootstrap summaries are descriptive cell-level stability only; no biological-replicate inference is available. UMAP is not used.
#
# ## Reader guide
#
# - **Purpose:** GSE249479 Phase 3B — PBS versus LPS descriptive ScGeo geometry in the frozen revision workflow.
# - **Inference scope:** GSE249479, a public human HSPC inflammatory xenograft dataset, remains descriptive_only because no recoverable biological-replicate identity was found. Cells, conditions, libraries, and inferred partitions are not replicates.
# - **Inputs:** The frozen compact expression object and lightweight representation object.
# - **Implementation:** `scripts/gse249479_scgeo_common.py`.
# - **Outputs:** Ignored `results/public_validation/gse249479_dataset_b/` artifacts.
# - **Frozen findings:** Retain the accepted descriptive TNF/LPS geometry, representation sensitivity, signature, abundance/distribution, and official R Augur evidence. The Python comparator remains supplementary only.
# - **Limitations:** No population-level biological inference is available; nested PCA views are not independent confirmations and UMAP is display-only.
#
# This source notebook is intentionally a thin, output-free entry point. The testable implementation is maintained in scripts/gse249479_scgeo_common.py. Executed review copies and generated artifacts are written under the ignored results directory.

# %%
from scripts.gse249479_scgeo_common import run_contrast
summary = run_contrast('LPS')
summary
