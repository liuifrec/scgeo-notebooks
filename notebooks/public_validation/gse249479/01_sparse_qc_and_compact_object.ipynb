# %% [markdown]
# # GSE249479 Phase 2B/2C: sparse QC and compact object
#
# This notebook performs sparse-only QC, applies prespecified study-grounded filters, flags but does not automatically exclude percentile-based library-size extremes, selects HVGs from raw sparse counts, and atomically writes a compact sparse object. All findings remain `descriptive_only`. It does not run PCA, diffusion maps, scVI, UMAP, ScGeo, comparators, Harmony, Scanorama, or RNA velocity.
#
# ## Reader guide
#
# - **Purpose:** GSE249479 Phase 2B/2C: sparse QC and compact object in the frozen revision workflow.
# - **Inference scope:** GSE249479, a public human HSPC inflammatory xenograft dataset, remains descriptive_only because no recoverable biological-replicate identity was found. Cells, conditions, libraries, and inferred partitions are not replicates.
# - **Inputs:** The immutable source H5AD and the preceding audit/QC artifacts.
# - **Implementation:** `scripts/gse249479_qc_common.py`.
# - **Outputs:** Ignored `results/public_validation/gse249479_dataset_b/` artifacts.
# - **Frozen findings:** Retain the accepted descriptive TNF/LPS geometry, representation sensitivity, signature, abundance/distribution, and official R Augur evidence. The Python comparator remains supplementary only.
# - **Limitations:** No population-level biological inference is available; nested PCA views are not independent confirmations and UMAP is display-only.
#
# This source notebook is intentionally a thin, output-free entry point. The testable implementation is maintained in scripts/gse249479_qc_common.py. Executed review copies and generated artifacts are written under the ignored results directory.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
sys.path.insert(0, str(ROOT / 'scripts'))
from gse249479_qc_common import run_sparse_qc_and_compact

# %%
summary = run_sparse_qc_and_compact()
summary
