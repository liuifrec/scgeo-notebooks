# %% [markdown]
# # Dataset B GSE249479 Phase 2D/2E: annotation, signatures, and representation plan
#
# This notebook scores explicitly sourced study, literature, and marker-based gene sets on sparse counts; assigns only conservative marker-based labels with confidence; and writes a representation plan without executing any representation. No inferential biological p-values are calculated, and all results remain `descriptive_only`.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
sys.path.insert(0, str(ROOT / 'scripts'))
from gse249479_qc_common import run_annotation_and_signatures

# %%
summary = run_annotation_and_signatures()
summary
