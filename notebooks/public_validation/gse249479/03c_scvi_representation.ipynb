# %% [markdown]
# # Dataset B Phase 3A: scVI representation
#
# This notebook runs alone in the `sc_atac` environment. It uses raw sparse counts for the same 3,000 HVGs, no batch covariate, a fixed 20-dimensional latent space, early stopping, batch size 256 and zero workers. CUDA is used only if locally available; otherwise CPU is recorded. No dense normalized-expression matrix is stored.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
sys.path.insert(0, str(ROOT / 'scripts'))
from gse249479_representation_common import run_scvi

# %%
summary = run_scvi()
summary
