# %% [markdown]
# # Dataset B Phase 3A: representation quality and lightweight object
#
# After all heavy representations finish, this fresh-process stage computes descriptive quality metrics, rare-state sensitivity and display-only UMAPs. It assembles an expression-free representation H5AD. Condition mixing is reported without assuming that mixing is desirable, and no ScGeo or comparator analysis is run.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
sys.path.insert(0, str(ROOT / 'scripts'))
from gse249479_representation_common import run_quality

# %%
summary = run_quality()
summary
