# %% [markdown]
# # Dataset B Phase 3C — Augur-inspired Python sensitivity implementation
#
# This supplementary sensitivity notebook uses Augur-like balanced subsampling and headline random-forest settings with sparse 3,000-HVG expression. It matches 50 subsamples, 20 cells per condition, three CV folds, a 0.5 variance-selection target, 50% random feature sampling, 100 trees, and mtry 2. It is not an exact or faithful implementation of official Augur: variable features are the upper half by raw sparse variance rather than LOESS residuals, and the forest engine, seed schedule, and CV construction differ. Official R Augur 1.0.3 at commit b252b84e4af687d9817813b1db409267eb44ec3f is the canonical Dataset B comparator. Python AUC spread is computational cell-resampling stability only; all results are descriptive_only.

# %%
from scripts.gse249479_augur_common import run_augur
summary = run_augur()
summary
